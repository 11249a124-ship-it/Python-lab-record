# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a124-ship-it/Python-lab-record/blob/main/Exp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1="""1.Calculation of Test Average: Write a python program to find the best of two test

# %%
m1 = int(input("Enter marks for Test 1: "))
m2 = int(input("Enter marks for Test 2: "))
m3 = int(input("Enter marks for Test 3: "))
minimum = min(m1, m2, m3)
sum_best_two = m1 + m2 + m3 - minimum
average_best_two = sum_best_two / 2
print("Average of best two test marks is:", average_best_two)
# Out:
# Enter marks for Test 1: 12
# Enter marks for Test 2: 13
# Enter marks for Test 3: 14
# Average of best two test marks is: 13.5
